# %%
from collections import defaultdict
import numpy as np
from matplotlib import pyplot as plt

# %%
ts_time = defaultdict(float)
for i in range(1,4):
    for line in open(str(i)+".txt"):
        #print(line)
        thing = line.split()
        msg = thing[1]
        time = float(thing[4])
        # print(thing)
        # # print(msg)
        # # print(time)
        ts_time[msg] = max(0,ts_time[msg],time)
        #print(ts_time[msg])
#print(len(ts_time))

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

data = np.array(list(ts_time.values()))
# print(data)
# print(len(data))
count, bins_count = np.histogram(data, bins=100)
pdf = count / sum(count)
cdf = np.cumsum(pdf)*100
plt.plot(bins_count[1:], cdf, label="CDF")
plt.legend()

plt.xlabel("transaction time (s)")
plt.ylabel("cdf percentage %")
plt.title(f'cdf of transaction time in scenerio 1') 
plt.savefig(f'Scenerio 1.png')
plt.show()
